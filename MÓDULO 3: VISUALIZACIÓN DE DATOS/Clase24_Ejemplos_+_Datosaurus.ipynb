# %% [markdown]
# <a href="https://colab.research.google.com/github/Shicamaru09/Python_essential/blob/main/M%C3%93DULO%203%3A%20VISUALIZACI%C3%93N%20DE%20DATOS/Clase24_Ejemplos_%2B_Datosaurus.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![picture](https://drive.google.com/uc?export=view&id=1KaUW3_JAieeY7WVNfoRiTSr2JsaeAcXi)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Ejemplos + Datosaurus
# # Módulo 3 - Sesión 4
# ## Profesor: Germain Garcia Zanabria

# %%
import matplotlib.pyplot as plt

# Datos de ejemplo
x = [1, 2, 3, 4, 5]
y = [2, 3, 5, 7, 11]

# Crear el gráfico
plt.plot(x, y, marker='o', linestyle='--', color='#80b1d3', label='Crecimiento') # '-', '--', '-.', ':', 'None', ' ', '', 'solid', 'dashed', 'dashdot', 'dotted'

plt.xlabel('Días')  # Etiqueta del eje X
plt.ylabel('Valores')  # Etiqueta del eje Y
plt.title('Ejemplo de Gráfico de Líneas')  # Título del gráfico
plt.legend()  # Mostrar leyenda
# Añadir líneas de la cuadrícula
plt.grid(True)

# Mostrar el gráfico
plt.show()

# %% [markdown]
# # Función Cuadrática

# %%
import numpy as np

# Parámetros de la función cuadrática
a, b, c = 1, -3, 2
x = np.linspace(-10, 10, 5)
y = a * x**2 + b * x + c

plt.plot(x, y,linestyle=':', marker='+',color='green')


plt.title('Función Cuadrática')

plt.xlabel('Eje x')
plt.ylabel('Eje y')


plt.grid(True)
plt.show() # cierre

# %% [markdown]
# # Función de Equilibrio de Mercado

# %%
import matplotlib.pyplot as plt
import numpy as np

# Oferta y demanda
x = np.linspace(0, 10, 100)
oferta = 2 * x + 5
demanda = -3 * x + 40


plt.plot(x, oferta, color ='r', label='Oferta')
plt.plot(x, demanda, color ='b', label='Demanda')


plt.title('Función de Equilibrio de Mercado')
plt.xlabel('Cantidad')
plt.ylabel('Precio')

plt.axvline(7, color='green', linestyle='--')
plt.axhline(19, color='g', linestyle='--')

plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Algo más allá
#
# Vamos a intentar ver ventas

# %%
import pandas as pd
np.random.seed(42)


fechas = pd.date_range(start="2024-01-01", periods=100, freq="D") # Fechas diarias (100 días)


serie_a = np.cumsum(np.random.randn(100)) + 50
serie_b = np.cumsum(np.random.randn(100)) + 40

df = pd.DataFrame({
    "Fecha": fechas,
    "Serie A": serie_a,
    "Serie B": serie_b
})

# %%
df.head()
# Out:
#        Fecha    Serie A    Serie B
# 0 2024-01-01  50.496714  28.584629
# 1 2024-01-02  50.358450  28.163984
# 2 2024-01-03  51.006138  27.821269
# 3 2024-01-04  52.529168  27.018992
# 4 2024-01-05  52.295015  26.857706

# %%
plt.figure(figsize=(10, 5))

plt.plot(df["Fecha"], df["Serie A"], label="Ventas de A")
plt.plot(df["Fecha"], df["Serie B"], label="Ventas de B")

plt.xlabel("Fecha")
plt.ylabel("ventas")
plt.title("Series temporales de ventas")
plt.grid(linestyle='--',color='#bebada',linewidth=1) ##plt.grid(color = 'green', linestyle = '--', linewidth = 0.5)

plt.legend()

plt.xticks(rotation=90)
#plt.tight_layout()
plt.show()

# %% [markdown]
# # Función de Costo Marginal
# El Costo Marginal (MC, por sus siglas en inglés de "Marginal Cost") es una herramienta económica que mide el cambio en el costo total de producción cuando se produce una unidad adicional de un bien o servicio. Es una función fundamental en la teoría de la producción y se utiliza para optimizar las decisiones de producción y fijación de precios.
#
#
# Una forma común es
# 𝑀𝐶(𝑄)= 𝑐 + 𝑑 𝑄

# %%
import matplotlib.pyplot as plt
import numpy as np

# Parámetros de la función de costo marginal
c, d = 10, 2
Q = np.linspace(0, 10, 100)
MC = c + d * Q

plt.plot(Q, MC)
plt.title('Función de Costo Marginal')
plt.xlabel('Cantidad Producida (Q)')
plt.ylabel('Costo Marginal (MC)')
plt.grid(True)
plt.show()

# %% [markdown]
# # Subplots

# %%
x = np.linspace(-10, 10, 400)
y1 = 2 * x + 1
y2 = -x + 3
y3 = 0.5 * x *x - 2
y4 = 3 * x + 4

fig, axs = plt.subplots(2,2,figsize=(10, 8))

# Función Lineal 1
axs[0, 0].plot(x, y1, 'b-')
axs[0, 0].set_title('y = 2x + 1')
axs[0, 0].set_xlabel('x')
axs[0, 0].set_ylabel('y')
axs[0, 0].grid(True)

# Función Lineal 2
axs[0, 1].plot(x, y2, 'r-')
axs[0, 1].set_title('y = -x + 3')
axs[0, 1].set_xlabel('x')
axs[0, 1].set_ylabel('y')
axs[0, 1].grid(True)

# Función Lineal 3
axs[1, 0].plot(x, y3, 'g-')
axs[1, 0].set_title('y = 0.5x*x - 2')
axs[1, 0].set_xlabel('x')
axs[1, 0].set_ylabel('y')
axs[1, 0].grid(True)

# Función Lineal 4
axs[1, 1].plot(x, y4, 'm-')
axs[1, 1].set_title('y = 3x + 4')
axs[1, 1].set_xlabel('x')
axs[1, 1].set_ylabel('y')
axs[1, 1].grid(True)

plt.tight_layout()
plt.show()

# %%
#import matplotlib.pyplot as plt
#import numpy as np

# Crear valores de x
x = np.linspace(-10, 10, 400)

# Definir las funciones lineales
y1 = 2 * x + 1
y2 = -x + 3
y3 = 0.5 * x *x - 2
y4 = 3 * x + 4

# Crear una figura con 4 subplots
fig, axs = plt.subplots(2, 2, figsize=(10, 8))

# Función Lineal 1
axs[0, 0].plot(x, y1, 'b-')
axs[0, 0].set_title('y = 2x + 1')
axs[0, 0].set_xlabel('x')
axs[0, 0].set_ylabel('y')
axs[0, 0].grid(True)

# Función Lineal 2
axs[0, 1].plot(x, y2, 'r-')
axs[0, 1].set_title('y = -x + 3')
axs[0, 1].set_xlabel('x')
axs[0, 1].set_ylabel('y')
axs[0, 1].grid(True)

# Función Lineal 3
axs[1, 0].plot(x, y3, 'g-')
axs[1, 0].set_title('y = 0.5x*x - 2')
axs[1, 0].set_xlabel('x')
axs[1, 0].set_ylabel('y')
axs[1, 0].grid(True)

# Función Lineal 4
axs[1, 1].plot(x, y4, 'm-')
axs[1, 1].set_title('y = 3x + 4')
axs[1, 1].set_xlabel('x')
axs[1, 1].set_ylabel('y')
axs[1, 1].grid(True)

# Ajustar el layout para evitar superposiciones
plt.tight_layout()

# Mostrar el gráfico
plt.show()

# %% [markdown]
# # Gráfico de Dispersión

# %%
# Simular datos de horas de estudio y calificaciones
np.random.seed(0)

horas_estudio = np.random.randint(1, 10, 50) #x
calificaciones = horas_estudio * 10 + np.random.normal(0, 5, 50) # y

# Crear un DataFrame con los datos
data = {
    'Horas de Estudio': horas_estudio,
    'Calificaciones': calificaciones
}
df = pd.DataFrame(data)
df.head()
# Out:
#    Horas de Estudio  Calificaciones
# 0                 6       57.295419
# 1                 1        3.383863
# 2                 4       39.436005
# 3                 4       44.536730
# 4                 8       84.076350

# %%
# Crear una figura
plt.figure(figsize=(8, 4))

# Crear el gráfico de dispersión
plt.scatter(df['Horas de Estudio'], df['Calificaciones'], color='b', marker='x')

# Añadir título y etiquetas de los ejes
plt.title('Relación entre Horas de Estudio y Calificaciones')
plt.xlabel('Horas de Estudio')
plt.ylabel('Calificaciones')

# Añadir una cuadrícula
plt.grid(True)

# Mostrar el gráfico
plt.show()

# %% [markdown]
# # Gráfico Histograma

# %%
import matplotlib.pyplot as plt
import numpy as np

# (calificaciones de estudiantes)
np.random.seed(42)
calificaciones = np.random.normal(15, 5, 100)  # Media = 70, Desviación estándar = 10, Número de datos = 100
calificaciones
# Out:
# array([17.48357077, 14.30867849, 18.23844269, 22.61514928, 13.82923313,
#        13.82931522, 22.89606408, 18.83717365, 12.65262807, 17.71280022,
#        12.68291154, 12.67135123, 16.20981136,  5.43359878,  6.37541084,
#        12.18856235,  9.9358444 , 16.57123666, 10.45987962,  7.93848149,
#        22.32824384, 13.8711185 , 15.33764102,  7.87625907, 12.27808638,
#        15.55461295,  9.24503211, 16.87849009, 11.99680655, 13.54153125,
#        11.99146694, 24.26139092, 14.93251388,  9.71144536, 19.11272456,
#         8.89578175, 16.04431798,  5.20164938,  8.35906976, 15.98430618,
#        18.6923329 , 15.85684141, 14.42175859, 13.49448152,  7.60739005,
#        11.40077896, 12.69680615, 20.28561113, 16.71809145,  6.18479922,
#        16.62041985, 13.0745886 , 11.61539   , 18.05838144, 20.15499761,
#        19.6564006 , 10.80391238, 13.45393812, 16.65631716, 19.87772564,
#        12.60412881, 14.07170512,  9.46832513,  9.01896688, 19.06262911,
#        21.78120014, 14.63994939, 20.01766449, 16.80818013, 11.77440123,
#        16.80697803, 22.69018283, 14.8208698 , 22.82321828,  1.90127448,
#        19.10951252, 15.43523534, 13.50496325, 15.45880388,  5.06215543,
#        13.90164056, 16.78556286, 22.38947022, 12.40864891, 10.95753199,
#        12.49121478, 19.57701059, 16.64375555, 12.35119898, 17.56633717,
#        15.48538775, 19.84322495, 11.48973453, 13.36168927, 13.03945923,
#         7.68242526, 16.48060139, 16.30527636, 15.02556728, 13.82706433])

# %%
# Crear una figura
plt.figure(figsize=(10, 6))



# Crear el histograma
plt.hist(calificaciones, bins=30, edgecolor='gray')

# Añadir título y etiquetas de los ejes
#plt.title('Distribución de Calificaciones de Estudiantes')
#plt.xlabel('Calificaciones')
#plt.ylabel('Frecuencia')

#plt.grid(True)

# Mostrar el gráfico
plt.show()

# %% [markdown]
# # Box Plot

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

np.random.seed(42)

datos = {
    'Matematicas': np.random.normal(70, 10, 100),
    'Ciencias': np.random.normal(65, 15, 100),
    'Ingles': np.random.normal(75, 12, 100)
}

df = pd.DataFrame(datos)
df.head()
# Out:
#    Matematicas   Ciencias     Ingles
# 0    74.967142  43.769439  79.293448
# 1    68.617357  58.690320  81.729414
# 2    76.476885  59.859282  87.996615
# 3    85.230299  52.965841  87.645625
# 4    67.658466  62.580714  58.467968

# %%
plt.figure(figsize=(10, 6))

data_to_plot = [df['Matematicas'], df['Ciencias'],df['Ingles']]



plt.boxplot(data_to_plot, labels=['Matemáticas', 'Ciencias','Ingles'])

# Añadir título y etiquetas de los ejes
plt.title('Distribución de Calificaciones por Asignatura')
plt.xlabel('Asignatura')
plt.ylabel('Calificaciones')
plt.grid(True)
plt.show()
# Out:
# /tmp/ipython-input-71-511996941.py:7: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(data_to_plot, labels=['Matemáticas', 'Ciencias','Ingles'])

# %% [markdown]
# # Datosaurus
# Es un conjunto de datos creado para ilustrar la importancia de visualizar los datos en lugar de confiar únicamente en las estadísticas resumidas. El conjunto de datos original, conocido como "Datasaurus," fue diseñado para demostrar que diferentes conjuntos de datos pueden tener las mismas estadísticas descriptivas (media, varianza, correlación, etc.) pero pueden ser muy diferentes cuando se visualizan gráficamente.

# %%
# Conectar con Google Drive
PATH = 'https://raw.githubusercontent.com/germaingarcia/Files_Lectures/main/Datasaurus_data.csv'

# %%
from IPython.display import display
import pandas as pd
import numpy as np
import xml.etree.ElementTree as ET

# Lee el archivo .csv
df = pd.read_csv(PATH)

# Muestra las primeras filas del DataFrame para verificar que se haya cargado correctamente
df
# Out:
#          dataset          x          y
# 0           dino  55.384600  97.179500
# 1           dino  51.538500  96.025600
# 2           dino  46.153800  94.487200
# 3           dino  42.820500  91.410300
# 4           dino  40.769200  88.333300
# ...          ...        ...        ...
# 1699  slant_down  39.596501  32.136132
# 1700  slant_down  95.593416  33.234129
# 1701  slant_down  52.772288  99.613472
# 1702  slant_down  53.178614  98.603861
# 1703  slant_down  37.627053  93.060673
#
# [1704 rows x 3 columns]

# %%
df_dino = df[df['dataset']=='dino']
df_dino
# Out:
#     dataset        x        y
# 0      dino  55.3846  97.1795
# 1      dino  51.5385  96.0256
# 2      dino  46.1538  94.4872
# 3      dino  42.8205  91.4103
# 4      dino  40.7692  88.3333
# ..      ...      ...      ...
# 137    dino  39.4872  25.3846
# 138    dino  91.2821  41.5385
# 139    dino  50.0000  95.7692
# 140    dino  47.9487  95.0000
# 141    dino  44.1026  92.6923
#
# [142 rows x 3 columns]

# %%
df_dino = df[df['dataset']=='dino']
plt.scatter(df_dino['x'], df_dino['y'], color='#fb8072', marker='x',edgecolor='gray')

#plt.grid(True)
# Mostrar el
plt.show()
# Out:
# /tmp/ipython-input-78-4001671503.py:2: UserWarning: You passed a edgecolor/edgecolors ('gray') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   plt.scatter(df_dino['x'], df_dino['y'], color='#fb8072', marker='x',edgecolor='gray')

# %%
datasets = df['dataset'].unique()
datasets

# %% [markdown]
# ##  1. Cargar y visualizar el conjunto de datos

# %%
import pandas as pd
import matplotlib.pyplot as plt

print(df.head())

datasets = df['dataset'].unique()

# Crear la figura y los subplots
fig, axes = plt.subplots(nrows=3, ncols=4, figsize=(14, 10))
axes = axes.flatten()

# Mapear los datos en cada subplot
for i, dataset in enumerate(datasets):
    subset = df[df['dataset'] == dataset]
    axes[i].scatter(subset['x'], subset['y'], color='red', marker='o',edgecolor='white')
    axes[i].set_title(dataset)
    axes[i].set_xlabel('x')
    axes[i].set_ylabel('y')

# Ajustar el diseño para evitar solapamientos
plt.tight_layout(rect=[0, 0, 1, 0.96])

# Ajustar el título
fig.suptitle('Datasaurus Dozen: Conjuntos de Datos Diferentes con Estadísticas Resumidas Idénticas', fontsize=16)

# Mostrar el gráfico
plt.show()
# Out:
#   dataset        x        y
# 0    dino  55.3846  97.1795
# 1    dino  51.5385  96.0256
# 2    dino  46.1538  94.4872
# 3    dino  42.8205  91.4103
# 4    dino  40.7692  88.3333

# %% [markdown]
# ##  2. Histograms for the x and y coordinates for one of the datasets:

# %%
dino_data = df[df['dataset'] == 'dino']


fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# Histograma para los valores de 'x'
axes[0].hist(dino_data['x'], bins=10, color='green',edgecolor='white')
axes[0].set_title('Histogram of x values for dino dataset')
axes[0].set_xlabel('x values')
axes[0].set_ylabel('Frequency')

# Histograma para los valores de 'y'
axes[1].hist(dino_data['y'], bins=10, edgecolor='black')
axes[1].set_title('Histogram of y values for dino dataset')
axes[1].set_xlabel('y values')
axes[1].set_ylabel('Frequency')

# Ajustar el diseño para evitar solapamientos
plt.tight_layout()

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ## 3. Subplots para comparar diagramas de dispersión de algunos conjuntos de datos uno al lado del otro

# %%
datasets = ['dino', 'dots', 'x_shape']

fig, axes = plt.subplots(1, 3, figsize=(18, 6))

for ax, dataset in zip(axes, datasets):
    data = df[df['dataset'] == dataset]
    ax.scatter(data['x'], data['y'])
    ax.set_title(f'Scatter plot para {dataset}')
    ax.set_xlabel('x')
    ax.set_ylabel('y')

# Ajustar el diseño para evitar solapamientos
plt.tight_layout()

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ## 4. Box plot para todas las variables X de los diferentes datasets:

# %%
data_to_plot = [df[df['dataset'] == dataset]['x'] for dataset in datasets]

# %%
# Crear un box plot de la variable 'x' para todos los datasets
plt.figure(figsize=(12, 6))
datasets = df['dataset'].unique()

# Crear una lista de listas para los datos de 'x'
data_to_plot = [df[df['dataset'] == dataset]['x'] for dataset in datasets]

plt.boxplot(data_to_plot, labels=datasets,patch_artist=True)

plt.title('Box Plot de la Variable X en Todos los Datasets')
plt.xlabel('Dataset')
plt.ylabel('X')
plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# ## 5. Box plot para todas las variables Y de los diferentes datasets:

# %%
# Crear un box plot de la variable 'y' para todos los datasets

plt.figure(figsize=(12, 6))

datasets = df['dataset'].unique()
data = [df.loc[df['dataset'] == d, 'y'].values for d in datasets]

#sns.boxplot(x='dataset', y='y', data=df)
plt.boxplot(data, labels=datasets)
plt.title('Box Plot de la Variable Y en Todos los Datasets')
plt.xlabel('Dataset')
plt.ylabel('Y')
plt.xticks(rotation=45)
plt.show()
